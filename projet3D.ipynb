# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Charger l'image
image_path = "th.jpeg"  # Remplacer par le chemin correct
img = cv2.imread(image_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Appliquer un filtre de détection de contours (Canny)
edges = cv2.Canny(gray, 50, 150)

# Générer une carte de profondeur simple (approche basée sur les gradients)
depth_map = cv2.GaussianBlur(edges, (15, 15), 0)

# Normaliser la profondeur pour Matplotlib
depth_map = cv2.normalize(depth_map, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX)

# Affichage en 3D avec Matplotlib
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Créer un meshgrid pour les coordonnées
h, w = depth_map.shape
X, Y = np.meshgrid(range(w), range(h))

# Utiliser la carte de profondeur comme axe Z
ax.plot_surface(X, Y, -depth_map, rstride=1, cstride=1, cmap='viridis', edgecolor='none')

ax.set_title("Représentation 3D")
plt.show()
